# %%
import pandas as pd
import numpy as np

import json
from pprint import pprint
import matplotlib.pyplot as plt

import seaborn as sb

# %%
file = "RatingsLatLongYear.js"
# Open JSON Files
with open(file) as f:
    data = json.load(f)

beerData = pd.DataFrame(data)
beerData.head(25)
# Out:
#     Average ABV  Average Calories  Average IBU  Average Score  Google Rating  \
# 0      6.540741        196.222222    30.687500       2.968000            4.6
# 1      7.925000        237.750000    36.950000       3.612000            4.8
# 2      5.731250        171.937500    21.300000       3.082857            4.5
# 3      6.146154        184.769231    38.181818       3.050833            4.1
# 4      6.183333        185.500000    46.461538       3.218500            4.6
# 5      7.003125        210.093750    44.769231       3.066667            4.6
# 6      6.077778        182.166667    25.250000       3.174000            4.7
# 7      7.985000        239.550000    42.529412       3.269000            4.7
# 8      6.493333        194.800000    33.642857       3.075714            4.7
# 9      7.874359        236.230769    44.812500       3.198611            4.6
# 10     5.666667        170.000000          NaN       3.108333            4.5
# ...

# %%
beerData.loc[17,'lat'] = 39.0185
beerData.loc[17,'long'] = -94.2782
beerData.head(25)
# Out:
#     Average ABV  Average Calories  Average IBU  Average Score  Google Rating  \
# 0      6.540741        196.222222    30.687500       2.968000            4.6
# 1      7.925000        237.750000    36.950000       3.612000            4.8
# 2      5.731250        171.937500    21.300000       3.082857            4.5
# 3      6.146154        184.769231    38.181818       3.050833            4.1
# 4      6.183333        185.500000    46.461538       3.218500            4.6
# 5      7.003125        210.093750    44.769231       3.066667            4.6
# 6      6.077778        182.166667    25.250000       3.174000            4.7
# 7      7.985000        239.550000    42.529412       3.269000            4.7
# 8      6.493333        194.800000    33.642857       3.075714            4.7
# 9      7.874359        236.230769    44.812500       3.198611            4.6
# 10     5.666667        170.000000          NaN       3.108333            4.5
# ...

# %%
fringe = pd.DataFrame([{"Average ABV": 0, "Average Calories": 0, "Average IBU": 0, "Average Score": 0,
                 "Google Rating": 4.8, "Name": "Fringe Beerworks", "Total Ratings": 0,
                 "lat":38.9128, "long":-94.3766, "Year Opened": 2016}])

smoke = pd.DataFrame([{"Average ABV": 0, "Average Calories": 0, "Average IBU": 0, "Average Score": 0,
                 "Google Rating": 4.3, "Name": "Smoke Brewing", "Total Ratings": 0,
                 "lat":38.9131, "long":-94.3778, "Year Opened": 2016}])

newaxiom = pd.DataFrame([{"Average ABV": 0, "Average Calories": 0, "Average IBU": 0, "Average Score": 0,
                 "Google Rating": 4.8, "Name": "New Axiom", "Total Ratings": 0,
                 "lat":38.9207, "long":-94.3588, "Year Opened": 2018}])

beerData = beerData.append(fringe)
beerData = beerData.append(smoke)
beerData = beerData.append(newaxiom)


beerData.head(25)
# Out:
#     Average ABV  Average Calories  Average IBU  Average Score  Google Rating  \
# 0      6.540741        196.222222    30.687500       2.968000            4.6
# 1      7.925000        237.750000    36.950000       3.612000            4.8
# 2      5.731250        171.937500    21.300000       3.082857            4.5
# 3      6.146154        184.769231    38.181818       3.050833            4.1
# 4      6.183333        185.500000    46.461538       3.218500            4.6
# 5      7.003125        210.093750    44.769231       3.066667            4.6
# 6      6.077778        182.166667    25.250000       3.174000            4.7
# 7      7.985000        239.550000    42.529412       3.269000            4.7
# 8      6.493333        194.800000    33.642857       3.075714            4.7
# 9      7.874359        236.230769    44.812500       3.198611            4.6
# 10     5.666667        170.000000          NaN       3.108333            4.5
# ...

# %%
beerData = beerData.reset_index(drop=True)
beerData.head(25)
# Out:
#     Average ABV  Average Calories  Average IBU  Average Score  Google Rating  \
# 0      6.540741        196.222222    30.687500       2.968000            4.6
# 1      7.925000        237.750000    36.950000       3.612000            4.8
# 2      5.731250        171.937500    21.300000       3.082857            4.5
# 3      6.146154        184.769231    38.181818       3.050833            4.1
# 4      6.183333        185.500000    46.461538       3.218500            4.6
# 5      7.003125        210.093750    44.769231       3.066667            4.6
# 6      6.077778        182.166667    25.250000       3.174000            4.7
# 7      7.985000        239.550000    42.529412       3.269000            4.7
# 8      6.493333        194.800000    33.642857       3.075714            4.7
# 9      7.874359        236.230769    44.812500       3.198611            4.6
# 10     5.666667        170.000000          NaN       3.108333            4.5
# ...

# %%
beerData.to_json("year2.js", orient='records')
